# %%
# !pip install torch torchaudio torchcodec
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 22.6 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import torch
import torchaudio
import torchcodec

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-1d4b4820-fba4-413a-90d1-64bcef51785b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1d4b4820-fba4-413a-90d1-64bcef51785b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
audio_file = 'misc/audiomass-output.wav'
waveform, sample_rate = torchaudio.load(audio_file)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/torchaudio/_torchcodec.py in load_with_torchcodec(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     115     try:
# --> 116         decoder = AudioDecoder(uri)
#     117     except Exception as e:
#
# /usr/local/lib/python3.12/dist-packages/torchcodec/decoders/_audio_decoder.py in __init__(self, source, stream_index, sample_rate, num_channels)
#      63         torch._C._log_api_usage_once("torchcodec.decoders.AudioDecoder")
# ---> 64         self._decoder = create_decoder(source=source, seek_mode="approximate")
#      65
#
# /usr/local/lib/python3.12/dist-packages/torchcodec/decoders/_decoder_utils.py in create_decoder(source, seek_mode)
#      28     if isinstance(source, str):
# ---> 29         return core.create_from_file(source, seek_mode)
# ...

# %%
model = torchaudio.models.ConvTasNet(
    num_sources = 2
)

# %% [markdown]
# # Speech Seperation Experiments

# %% [markdown]
# In this file, we will run basic experiments for speech seperation frameworks. This will detemrine which framwork we will be using for our app:
#
# - [SpeechBrain's SepFormer](https://github.com/speechbrain/speechbrain)
# - [FaceBook's Svoice](https://github.com/facebookresearch/svoice)

# %% [markdown]
# ### SepFormer

# %%
# !pip install speechbrain
# %pip install torchaudio>=2.1.0,<2.9 torch>=2.1.0,<2.9
# !wget https://raw.githubusercontent.com/speechbrain/speechbrain/develop/requirements.txt
# !sed -i '/lint-requirements.txt/d' requirements.txt
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: speechbrain in /usr/local/lib/python3.12/dist-packages (1.0.3)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.12/dist-packages (from speechbrain) (1.2.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from speechbrain) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from speechbrain) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from speechbrain) (25.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from speechbrain) (1.16.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.12/dist-packages (from speechbrain) (0.2.1)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.12/dist-packages (from speechbrain) (2.9.0+cpu)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (from speechbrain) (2.9.0+cpu)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from speechbrain) (4.67.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from speechbrain) (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->speechbrain) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->speechbrain) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->speechbrain) (2.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->speechbrain) (1.2.0)
# Requirement already satisfied: ruamel.yaml<0.19.0,>=0.17.28 in /usr/local/lib/python3.12/dist-packages (from hyperpyyaml->speechbrain) (0.18.17)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.15 in /usr/local/lib/python3.12/dist-packages (from ruamel.yaml<0.19.0,>=0.17.28->hyperpyyaml->speechbrain) (0.2.15)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9->speechbrain) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.9->speechbrain) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->speechbrain) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->speechbrain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->speechbrain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub->speechbrain) (2026.1.4)
# /bin/bash: line 1: 2.9: No such file or directory

# %%
# !ls
# Out:
# '=2.1.0,'   requirements.txt   requirements.txt.1   sample_data

# %%
import torchaudio
if not hasattr(torchaudio, "list_audio_backends"):
    torchaudio.list_audio_backends = lambda: [""]

from speechbrain.pretrained import SepformerSeparation
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1621239477.py in <cell line: 0>()
#       3     torchaudio.list_audio_backends = lambda: [""]
#       4
# ----> 5 from speechbrain.pretrained import SepformerSeparation
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/__init__.py in <module>
#       4 import os
#       5
# ----> 6 from .core import Brain, Stage, create_experiment_directory, parse_arguments
#       7 from .utils.importutils import deprecated_redirect, lazy_export_all
#       8
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/core.py in <module>
#      48 from speechbrain.utils.profiling import prepare_profiler
#      49
# ---> 50 sb.utils.quirks.apply_quirks()
#      51
#      52 logger = get_logger(__name__)
#
# AttributeError: partially initialized module 'speechbrain' has no attribute 'utils' (most likely due to a circular import)

# %%
import torchaudio
from speechbrain.pretrained import SepformerSeparation as separator

if not hasattr(torchaudio, "list_audio_backends"):
    torchaudio.list_audio_backends = lambda: [""]  # type: ignore

# load mdoel
model = SepformerSeparation.from_hparams(
    source="speechbrain/sepformer-wsj02mix",
    savedir="pretrained_models/sepformer-wsj02mix",
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-863266295.py in <cell line: 0>()
#       1 import torchaudio
# ----> 2 from speechbrain.pretrained import SepformerSeparation as separator
#       3
#       4 if not hasattr(torchaudio, "list_audio_backends"):
#       5     torchaudio.list_audio_backends = lambda: [""]  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/__init__.py in <module>
#       4 import os
#       5
# ----> 6 from .core import Brain, Stage, create_experiment_directory, parse_arguments
#       7 from .utils.importutils import deprecated_redirect, lazy_export_all
#       8
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/core.py in <module>
#      37
#      38 import speechbrain as sb
# ---> 39 from speechbrain.dataio.dataloader import LoopedLoader, SaveableDataLoader
#      40 from speechbrain.dataio.sampler import (
#      41     DistributedSamplerWrapper,
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/dataio/dataloader.py in <module>
#      44
#      45 from speechbrain.dataio.batch import BatchsizeGuesser, PaddedBatch
# ---> 46 from speechbrain.dataio.dataset import DynamicItemDataset
#      47 from speechbrain.dataio.sampler import (
#      48     DistributedSamplerWrapper,
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/dataio/dataset.py in <module>
#      13 from torch.utils.data import Dataset
#      14
# ---> 15 from speechbrain.dataio.dataio import load_data_csv, load_data_json
#      16 from speechbrain.utils.data_pipeline import DataPipeline
#      17 from speechbrain.utils.data_utils import batch_shuffle
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/dataio/dataio.py in <module>
#      34 )
#      35
# ---> 36 check_torchaudio_backend()
#      37 logger = get_logger(__name__)
#      38
#
# /usr/local/lib/python3.12/dist-packages/speechbrain/utils/torch_audio_backend.py in check_torchaudio_backend()
#      55         )
#      56     elif torchaudio_major >= 2 and torchaudio_minor >= 1:
# ---> 57         available_backends = torchaudio.list_audio_backends()
#      58
#      59         if len(available_backends) == 0:
#
# AttributeError: module 'torchaudio' has no attribute 'list_audio_backends'
